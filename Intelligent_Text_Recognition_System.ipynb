# %% [markdown]
# <a href="https://colab.research.google.com/github/Rafna123/Intelligent-Text-Recognition-System/blob/main/Intelligent_Text_Recognition_System.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#This project develops an Intelligent Text Recognition system (OCR) that automatically extracts text from images or scanned documents.
#It leverages computer vision and AI techniques to recognize printed or handwritten text accurately,
#even in noisy backgrounds or varying fonts.

# %%
#step 1 install libraries
# !sudo apt install tesseract-ocr
# !pip install pytesseract Pillow
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# tesseract-ocr is already the newest version (4.1.1-2.1build1).
# 0 upgraded, 0 newly installed, 0 to remove and 35 not upgraded.
# ...

# %%
#step 2
#import libraries
import pytesseract
from PIL import Image
from google.colab import files
import matplotlib.pyplot as plt
# %matplotlib inline
import cv2

# %%
#step 3
#define a function to perform OCR , certain image texts all read
def perform_ocr(image_path):
  try:
    img=Image.open(image_path)
    text=pytesseract.image_to_string(img)
    return text
  except Exception as e:
    return f"Error during OCR: {e}"

# %%
#step 4 upload the image containing text
print("upload an image file containing text")
uploaded=files.upload()

if uploaded:
  uploaded_file_name=list(uploaded.keys())[0]
  print(f"uploaded image :{uploaded_file_name}")

  #optional display the uploaded image
  img=cv2.imread(uploaded_file_name)
  plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))
  plt.title("uploded image")
  plt.axis("off")
  plt.show()

  extracted_text=perform_ocr(uploaded_file_name)
  print("\n--Extracted text-- ")
  print(extracted_text)
else:
  print("not image file uploaded")
# Out:
# upload an image file containing text
#      <input type="file" id="files-2d71beeb-3d76-403f-bc67-967726944881" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2d71beeb-3d76-403f-bc67-967726944881">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# ...
